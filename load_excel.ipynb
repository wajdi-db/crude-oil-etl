# %%
display(dbutils.fs.ls("/Volumes/wajdi_bounouara/parex_resources/parex-demo-volume/"))

# %%
# Infer schema field name from the header row
df = spark.read.option("headerRows", 1).excel(
    "/Volumes/wajdi_bounouara/parex_resources/parex-demo-volume/sensor_readings_jan2026_5k.xlsx"
)

# %%
display(df)

# %%
df.selectExpr(
    "reading_id",
    "sensor_id",
    "unit_id",
    "refinery_id",
    "reading_timestamp",
    "reading_value",
    "reading_quality",
    "is_interpolated",
    "event_time",
    "null as processing_time",
).write.mode("append").insertInto(
    "wajdi_bounouara.parex_resources.fact_sensor_readings"
)
